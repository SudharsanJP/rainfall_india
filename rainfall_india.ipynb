# %%
#) prepratory
a_list = []
length = 10
for name in range(1,10):
    a_list.append("JAN")
print(a_list)

# %%
import simple_colors
print(simple_colors.red("------------rainfall in india - Mini ML Project ------------\n//GUVI//"))
# Out:
# ------------rainfall in india - Mini ML Project ------------
# //GUVI//

# %%
#)reading the dataset
import pandas as pd
df = pd.read_csv(r"D:\Sudharsan\Guvi_Data science\DS101_Sudharsan\Mainboot camp\capstone project\rainfall\rainfall in india 1901-2015.csv")
df
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
#         JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0     365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1     228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2     728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3     502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4     368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
# ...     ...    ...    ...    ...    ...    ...     ...      ...      ...
# 4111  350.2  254.0  255.2  117.4  184.3   14.9  1533.7      7.9    196.2
# 4112  231.5  381.2  179.8  145.9   12.4    8.8  1405.5     19.3     99.6
# 4113  296.4  154.4  180.0   72.8   78.1   26.7  1426.3     60.6    131.1
# 4114  116.1  466.1  132.2  169.2   59.0   62.3  1395.0     69.3     76.7
# 4115  257.5  146.4  160.4  165.4  231.0  159.0  1642.9      2.7    223.9
#
#       Jun-Sep  Oct-Dec
# 0      1696.3    980.3
# 1      2185.9    716.7
# 2      1874.0    690.6
# 3      1977.6    571.0
# 4      1624.9    630.8
# ...       ...      ...
# 4111   1013.0    316.6
# 4112   1119.5    167.1
# 4113   1057.0    177.6
# 4114    958.5    290.5
# 4115    860.9    555.4
#
# [4116 rows x 19 columns]

# %%
#) check for the null values
print(simple_colors.magenta(" check for the null values"))
df.isna().sum()
# Out:
#  check for the null values
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
#) filling the null values
df = df.ffill()
df = df.bfill()

# %%
#) check for the null values
print(simple_colors.magenta(" check for the null values"))
df.isna().sum()
# Out:
#  check for the null values
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# dtype: int64

# %%
#) year and JAN dataframe
jan_df = df[['SUBDIVISION','YEAR','JAN']]
jan_df

#) making JAN data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("JAN")
month_list
#) converting list into column
jan_df['month'] = month_list
jan_df

#) chanhing the column name JAN --> vol
jan_df.rename(columns = {'JAN':'vol'}, inplace = True)
jan_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\875756881.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\875756881.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jan_df.rename(columns = {'JAN':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR   vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   JAN
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0   JAN
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7   JAN
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   JAN
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3   JAN
# ...                         ...   ...   ...   ...
# 4111                LAKSHADWEEP  2011   5.1   JAN
# 4112                LAKSHADWEEP  2012  19.2   JAN
# 4113                LAKSHADWEEP  2013  26.2   JAN
# 4114                LAKSHADWEEP  2014  53.2   JAN
# 4115                LAKSHADWEEP  2015   2.2   JAN
#
# [4116 rows x 4 columns]

# %%
#) year and FEB dataframe
feb_df = df[['SUBDIVISION','YEAR','FEB']]
feb_df

#) making FEB data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("FEB")
month_list
#) converting list into column
feb_df['month'] = month_list
feb_df

#) chanhing the column name FEB --> vol
feb_df.rename(columns = {'FEB':'vol'}, inplace = True)
feb_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\1680641430.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feb_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\1680641430.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feb_df.rename(columns = {'FEB':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR    vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901   87.1   FEB
# 1     ANDAMAN & NICOBAR ISLANDS  1902  159.8   FEB
# 2     ANDAMAN & NICOBAR ISLANDS  1903  144.0   FEB
# 3     ANDAMAN & NICOBAR ISLANDS  1904   14.7   FEB
# 4     ANDAMAN & NICOBAR ISLANDS  1905    0.0   FEB
# ...                         ...   ...    ...   ...
# 4111                LAKSHADWEEP  2011    2.8   FEB
# 4112                LAKSHADWEEP  2012    0.1   FEB
# 4113                LAKSHADWEEP  2013   34.4   FEB
# 4114                LAKSHADWEEP  2014   16.1   FEB
# 4115                LAKSHADWEEP  2015    0.5   FEB
#
# [4116 rows x 4 columns]

# %%
#) year and MAR dataframe
mar_df = df[['SUBDIVISION','YEAR','MAR']]
mar_df

#) making MAR data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("MAR")
month_list
#) converting list into column
mar_df['month'] = month_list
mar_df

#) chanhing the column name MAR --> vol
mar_df.rename(columns = {'MAR':'vol'}, inplace = True)
mar_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\2312756729.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mar_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\2312756729.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mar_df.rename(columns = {'MAR':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR   vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901  29.2   MAR
# 1     ANDAMAN & NICOBAR ISLANDS  1902  12.2   MAR
# 2     ANDAMAN & NICOBAR ISLANDS  1903   0.0   MAR
# 3     ANDAMAN & NICOBAR ISLANDS  1904   0.0   MAR
# 4     ANDAMAN & NICOBAR ISLANDS  1905   3.3   MAR
# ...                         ...   ...   ...   ...
# 4111                LAKSHADWEEP  2011   3.1   MAR
# 4112                LAKSHADWEEP  2012   1.6   MAR
# 4113                LAKSHADWEEP  2013  37.5   MAR
# 4114                LAKSHADWEEP  2014   4.4   MAR
# 4115                LAKSHADWEEP  2015   3.7   MAR
#
# [4116 rows x 4 columns]

# %%
#) year and APR dataframe
apr_df = df[['SUBDIVISION','YEAR','APR']]
apr_df

#) making APR data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("APR")
month_list
#) converting list into column
apr_df['month'] = month_list
apr_df

#) chanhing the column name APR --> vol
apr_df.rename(columns = {'APR':'vol'}, inplace = True)
apr_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\4196538200.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apr_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\4196538200.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apr_df.rename(columns = {'APR':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR    vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901    2.3   APR
# 1     ANDAMAN & NICOBAR ISLANDS  1902    0.0   APR
# 2     ANDAMAN & NICOBAR ISLANDS  1903    1.0   APR
# 3     ANDAMAN & NICOBAR ISLANDS  1904  202.4   APR
# 4     ANDAMAN & NICOBAR ISLANDS  1905   26.9   APR
# ...                         ...   ...    ...   ...
# 4111                LAKSHADWEEP  2011   85.9   APR
# 4112                LAKSHADWEEP  2012   76.8   APR
# 4113                LAKSHADWEEP  2013    5.3   APR
# 4114                LAKSHADWEEP  2014   14.9   APR
# 4115                LAKSHADWEEP  2015   87.1   APR
#
# [4116 rows x 4 columns]

# %%
#) year and MAY dataframe
may_df = df[['SUBDIVISION','YEAR','MAY']]
may_df

#) making MAY data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("MAY")
month_list
#) converting list into column
may_df['month'] = month_list
may_df

#) chanhing the column name MAY --> vol
may_df.rename(columns = {'MAY':'vol'}, inplace = True)
may_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\2070047912.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   may_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\2070047912.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   may_df.rename(columns = {'MAY':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR    vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901  528.8   MAY
# 1     ANDAMAN & NICOBAR ISLANDS  1902  446.1   MAY
# 2     ANDAMAN & NICOBAR ISLANDS  1903  235.1   MAY
# 3     ANDAMAN & NICOBAR ISLANDS  1904  304.5   MAY
# 4     ANDAMAN & NICOBAR ISLANDS  1905  279.5   MAY
# ...                         ...   ...    ...   ...
# 4111                LAKSHADWEEP  2011  107.2   MAY
# 4112                LAKSHADWEEP  2012   21.2   MAY
# 4113                LAKSHADWEEP  2013   88.3   MAY
# 4114                LAKSHADWEEP  2014   57.4   MAY
# 4115                LAKSHADWEEP  2015  133.1   MAY
#
# [4116 rows x 4 columns]

# %%
#) year and JUN dataframe
jun_df = df[['SUBDIVISION','YEAR','JUN']]
jun_df

#) making JUN data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("JUN")
month_list
#) converting list into column
jun_df['month'] = month_list
jun_df

#) chanhing the column name JUN --> vol
jun_df.rename(columns = {'JUN':'vol'}, inplace = True)
jun_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\2269945530.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jun_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\2269945530.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jun_df.rename(columns = {'JUN':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR    vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901  517.5   JUN
# 1     ANDAMAN & NICOBAR ISLANDS  1902  537.1   JUN
# 2     ANDAMAN & NICOBAR ISLANDS  1903  479.9   JUN
# 3     ANDAMAN & NICOBAR ISLANDS  1904  495.1   JUN
# 4     ANDAMAN & NICOBAR ISLANDS  1905  628.7   JUN
# ...                         ...   ...    ...   ...
# 4111                LAKSHADWEEP  2011  153.6   JUN
# 4112                LAKSHADWEEP  2012  327.0   JUN
# 4113                LAKSHADWEEP  2013  426.2   JUN
# 4114                LAKSHADWEEP  2014  244.1   JUN
# 4115                LAKSHADWEEP  2015  296.6   JUN
#
# [4116 rows x 4 columns]

# %%
#) year and JUL dataframe
jul_df = df[['SUBDIVISION','YEAR','JUL']]
jul_df

#) making JUL data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("JUL")
month_list

#) converting list into column
jul_df['month'] = month_list
jul_df

#) chanhing the column name JUL --> vol
jul_df.rename(columns = {'JUL':'vol'}, inplace = True)
jul_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\2465600905.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jul_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\2465600905.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jul_df.rename(columns = {'JUL':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR    vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901  365.1   JUL
# 1     ANDAMAN & NICOBAR ISLANDS  1902  228.9   JUL
# 2     ANDAMAN & NICOBAR ISLANDS  1903  728.4   JUL
# 3     ANDAMAN & NICOBAR ISLANDS  1904  502.0   JUL
# 4     ANDAMAN & NICOBAR ISLANDS  1905  368.7   JUL
# ...                         ...   ...    ...   ...
# 4111                LAKSHADWEEP  2011  350.2   JUL
# 4112                LAKSHADWEEP  2012  231.5   JUL
# 4113                LAKSHADWEEP  2013  296.4   JUL
# 4114                LAKSHADWEEP  2014  116.1   JUL
# 4115                LAKSHADWEEP  2015  257.5   JUL
#
# [4116 rows x 4 columns]

# %%
#) year and AUG dataframe
aug_df = df[['SUBDIVISION','YEAR','AUG']]
aug_df

#) making AUG data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("AUG")
month_list

#) converting list into column
aug_df['month'] = month_list
aug_df

#) chanhing the column name AUG --> vol
aug_df.rename(columns = {'AUG':'vol'}, inplace = True)
aug_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\3635545254.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aug_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\3635545254.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aug_df.rename(columns = {'AUG':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR    vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901  481.1   AUG
# 1     ANDAMAN & NICOBAR ISLANDS  1902  753.7   AUG
# 2     ANDAMAN & NICOBAR ISLANDS  1903  326.7   AUG
# 3     ANDAMAN & NICOBAR ISLANDS  1904  160.1   AUG
# 4     ANDAMAN & NICOBAR ISLANDS  1905  330.5   AUG
# ...                         ...   ...    ...   ...
# 4111                LAKSHADWEEP  2011  254.0   AUG
# 4112                LAKSHADWEEP  2012  381.2   AUG
# 4113                LAKSHADWEEP  2013  154.4   AUG
# 4114                LAKSHADWEEP  2014  466.1   AUG
# 4115                LAKSHADWEEP  2015  146.4   AUG
#
# [4116 rows x 4 columns]

# %%
#) year and SEP dataframe
sep_df = df[['SUBDIVISION','YEAR','SEP']]
sep_df

#) making SEP data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("SEP")
month_list

#) converting list into column
sep_df['month'] = month_list
sep_df

#) chanhing the column name SEP --> vol
sep_df.rename(columns = {'SEP':'vol'}, inplace = True)
sep_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\4104715778.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sep_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\4104715778.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sep_df.rename(columns = {'SEP':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR    vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901  332.6   SEP
# 1     ANDAMAN & NICOBAR ISLANDS  1902  666.2   SEP
# 2     ANDAMAN & NICOBAR ISLANDS  1903  339.0   SEP
# 3     ANDAMAN & NICOBAR ISLANDS  1904  820.4   SEP
# 4     ANDAMAN & NICOBAR ISLANDS  1905  297.0   SEP
# ...                         ...   ...    ...   ...
# 4111                LAKSHADWEEP  2011  255.2   SEP
# 4112                LAKSHADWEEP  2012  179.8   SEP
# 4113                LAKSHADWEEP  2013  180.0   SEP
# 4114                LAKSHADWEEP  2014  132.2   SEP
# 4115                LAKSHADWEEP  2015  160.4   SEP
#
# [4116 rows x 4 columns]

# %%
#) year and OCT dataframe
oct_df = df[['SUBDIVISION','YEAR','OCT']]
oct_df

#) making OCT data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("OCT")
month_list

#) converting list into column
oct_df['month'] = month_list
oct_df

#) changing the column name OCT --> vol
oct_df.rename(columns = {'OCT':'vol'}, inplace = True)
oct_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\1783611402.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oct_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\1783611402.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oct_df.rename(columns = {'OCT':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR    vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901  388.5   OCT
# 1     ANDAMAN & NICOBAR ISLANDS  1902  197.2   OCT
# 2     ANDAMAN & NICOBAR ISLANDS  1903  181.2   OCT
# 3     ANDAMAN & NICOBAR ISLANDS  1904  222.2   OCT
# 4     ANDAMAN & NICOBAR ISLANDS  1905  260.7   OCT
# ...                         ...   ...    ...   ...
# 4111                LAKSHADWEEP  2011  117.4   OCT
# 4112                LAKSHADWEEP  2012  145.9   OCT
# 4113                LAKSHADWEEP  2013   72.8   OCT
# 4114                LAKSHADWEEP  2014  169.2   OCT
# 4115                LAKSHADWEEP  2015  165.4   OCT
#
# [4116 rows x 4 columns]

# %%
#) year and NOV dataframe
nov_df = df[['SUBDIVISION','YEAR','NOV']]
nov_df

#) making NOV data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("NOV")
month_list

#) converting list into column
nov_df['month'] = month_list
nov_df

#) changing the column name NOV --> vol
nov_df.rename(columns = {'NOV':'vol'}, inplace = True)
nov_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\252249391.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\252249391.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_df.rename(columns = {'NOV':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR    vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901  558.2   NOV
# 1     ANDAMAN & NICOBAR ISLANDS  1902  359.0   NOV
# 2     ANDAMAN & NICOBAR ISLANDS  1903  284.4   NOV
# 3     ANDAMAN & NICOBAR ISLANDS  1904  308.7   NOV
# 4     ANDAMAN & NICOBAR ISLANDS  1905   25.4   NOV
# ...                         ...   ...    ...   ...
# 4111                LAKSHADWEEP  2011  184.3   NOV
# 4112                LAKSHADWEEP  2012   12.4   NOV
# 4113                LAKSHADWEEP  2013   78.1   NOV
# 4114                LAKSHADWEEP  2014   59.0   NOV
# 4115                LAKSHADWEEP  2015  231.0   NOV
#
# [4116 rows x 4 columns]

# %%
#) year and DEC dataframe
dec_df = df[['SUBDIVISION','YEAR','DEC']]
dec_df

#) making DEC data in a column
month_list = []
length = 10
for name in range(0,4116):
    month_list.append("DEC")
month_list

#) converting list into column
dec_df['month'] = month_list
dec_df

#) changing the column name DEC --> vol
dec_df.rename(columns = {'DEC':'vol'}, inplace = True)
dec_df
# Out:
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\2619499135.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dec_df['month'] = month_list
# C:\Users\sjsud\AppData\Local\Temp\ipykernel_19308\2619499135.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dec_df.rename(columns = {'DEC':'vol'}, inplace = True)
#                     SUBDIVISION  YEAR    vol month
# 0     ANDAMAN & NICOBAR ISLANDS  1901   33.6   DEC
# 1     ANDAMAN & NICOBAR ISLANDS  1902  160.5   DEC
# 2     ANDAMAN & NICOBAR ISLANDS  1903  225.0   DEC
# 3     ANDAMAN & NICOBAR ISLANDS  1904   40.1   DEC
# 4     ANDAMAN & NICOBAR ISLANDS  1905  344.7   DEC
# ...                         ...   ...    ...   ...
# 4111                LAKSHADWEEP  2011   14.9   DEC
# 4112                LAKSHADWEEP  2012    8.8   DEC
# 4113                LAKSHADWEEP  2013   26.7   DEC
# 4114                LAKSHADWEEP  2014   62.3   DEC
# 4115                LAKSHADWEEP  2015  159.0   DEC
#
# [4116 rows x 4 columns]

# %%
#) concatenation of 12 dataframes
print(simple_colors.blue(" concatenation of 2 dataframes"))
new_df = pd.concat([jan_df, feb_df,mar_df,apr_df,
               may_df,jun_df,jul_df,aug_df,
               oct_df,sep_df,nov_df,dec_df], axis=0, ignore_index=True)
new_df
# Out:
#  concatenation of 2 dataframes
#                      SUBDIVISION  YEAR    vol month
# 0      ANDAMAN & NICOBAR ISLANDS  1901   49.2   JAN
# 1      ANDAMAN & NICOBAR ISLANDS  1902    0.0   JAN
# 2      ANDAMAN & NICOBAR ISLANDS  1903   12.7   JAN
# 3      ANDAMAN & NICOBAR ISLANDS  1904    9.4   JAN
# 4      ANDAMAN & NICOBAR ISLANDS  1905    1.3   JAN
# ...                          ...   ...    ...   ...
# 49387                LAKSHADWEEP  2011   14.9   DEC
# 49388                LAKSHADWEEP  2012    8.8   DEC
# 49389                LAKSHADWEEP  2013   26.7   DEC
# 49390                LAKSHADWEEP  2014   62.3   DEC
# 49391                LAKSHADWEEP  2015  159.0   DEC
#
# [49392 rows x 4 columns]

# %%
#) to change the order of column 
new_df.iloc[:,[0,1,3,2]]
# Out:
#                      SUBDIVISION  YEAR month    vol
# 0      ANDAMAN & NICOBAR ISLANDS  1901   JAN   49.2
# 1      ANDAMAN & NICOBAR ISLANDS  1902   JAN    0.0
# 2      ANDAMAN & NICOBAR ISLANDS  1903   JAN   12.7
# 3      ANDAMAN & NICOBAR ISLANDS  1904   JAN    9.4
# 4      ANDAMAN & NICOBAR ISLANDS  1905   JAN    1.3
# ...                          ...   ...   ...    ...
# 49387                LAKSHADWEEP  2011   DEC   14.9
# 49388                LAKSHADWEEP  2012   DEC    8.8
# 49389                LAKSHADWEEP  2013   DEC   26.7
# 49390                LAKSHADWEEP  2014   DEC   62.3
# 49391                LAKSHADWEEP  2015   DEC  159.0
#
# [49392 rows x 4 columns]

# %%
new_df['month'].unique()
# Out:
# array(['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'OCT',
#        'SEP', 'NOV', 'DEC'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#) andhaman nicobar rain data
andhaman_df = new_df[new_df['SUBDIVISION'] == 'ANDAMAN & NICOBAR ISLANDS']
andhaman_df
# Out:
#                      SUBDIVISION  YEAR    vol month
# 0      ANDAMAN & NICOBAR ISLANDS  1901   49.2   JAN
# 1      ANDAMAN & NICOBAR ISLANDS  1902    0.0   JAN
# 2      ANDAMAN & NICOBAR ISLANDS  1903   12.7   JAN
# 3      ANDAMAN & NICOBAR ISLANDS  1904    9.4   JAN
# 4      ANDAMAN & NICOBAR ISLANDS  1905    1.3   JAN
# ...                          ...   ...    ...   ...
# 45381  ANDAMAN & NICOBAR ISLANDS  2011  238.5   DEC
# 45382  ANDAMAN & NICOBAR ISLANDS  2012  187.3   DEC
# 45383  ANDAMAN & NICOBAR ISLANDS  2013   92.3   DEC
# 45384  ANDAMAN & NICOBAR ISLANDS  2014  100.4   DEC
# 45385  ANDAMAN & NICOBAR ISLANDS  2015  129.9   DEC
#
# [1320 rows x 4 columns]

# %%
#) andhaman nicobar plot
plt.figure(figsize=(15,10))
sns.scatterplot(data=andhaman_df,x="YEAR",y="vol",hue='month' )
plt.show()

# %%
#) andhaman rain data
andhaman_df = new_df[new_df['SUBDIVISION'] == 'ANDAMAN & NICOBAR ISLANDS']
andhaman_df
andhaman_rain = andhaman_df['vol'].mean()
print(f"andhaman rain: {andhaman_rain}")

#) arunachal rain data
arunachal_df = new_df[new_df['SUBDIVISION'] == 'ARUNACHAL PRADESH']
arunachal_rain = arunachal_df['vol'].mean()
print(f"arunachal rain: {arunachal_rain}")

#) assam rain data
assam_df = new_df[new_df['SUBDIVISION'] == 'ASSAM & MEGHALAYA']
assam_rain = assam_df['vol'].mean()
print(f"assam rain: {assam_rain}")

#) naga rain data
naga_df = new_df[new_df['SUBDIVISION'] == 'NAGA MANI MIZO TRIPURA']
naga_rain = naga_df['vol'].mean()
print(f"naga rain: {naga_rain}")

#) himalaya_rain rain data
himalaya_df = new_df[new_df['SUBDIVISION'] == 'SUB HIMALAYAN WEST BENGAL & SIKKIM']
himalaya_rain = himalaya_df['vol'].mean()
print(f"himalaya rain: {himalaya_rain}")

#) gangestic_rain rain data
gangestic_df = new_df[new_df['SUBDIVISION'] == 'GANGETIC WEST BENGAL']
gangestic_rain = gangestic_df['vol'].mean()
print(f"gangestic rain: {gangestic_rain}")

#) gangestic_rain rain data
jarkhand_df = new_df[new_df['SUBDIVISION'] == 'JHARKHAND']
jarkhand_rain = jarkhand_df['vol'].mean()
print(f"jarkhand rain: {jarkhand_rain}")

#) bihar_rain rain data
bihar_df = new_df[new_df['SUBDIVISION'] == 'BIHAR']
bihar_rain = bihar_df['vol'].mean()
print(f"bihar rain: {bihar_rain}")

#) bihar_rain rain data
eastup_df = new_df[new_df['SUBDIVISION'] == 'EAST UTTAR PRADESH']
eastup_rain = eastup_df['vol'].mean()
print(f"east UP rain: {eastup_rain}")

#) orissa rain data
orissa_df = new_df[new_df['SUBDIVISION'] == 'ORISSA']
orissa_rain = orissa_df['vol'].mean()
print(f"orissa rain: {orissa_rain}")

#) westup rain data
westup_df = new_df[new_df['SUBDIVISION'] == 'WEST UTTAR PRADESH']
westup_rain = westup_df['vol'].mean()
print(f"west UP rain: {westup_rain}")

#) uk rain data
uk_df = new_df[new_df['SUBDIVISION'] == 'UTTARAKHAND']
uk_rain = uk_df['vol'].mean()
print(f"uk rain: {uk_rain}")

#) haryana delhi and chandigarh rain data
har_df = new_df[new_df['SUBDIVISION'] == 'HARYANA DELHI & CHANDIGARH']
har_rain = har_df['vol'].mean()
print(f"haryana delhi and chandigarh rain: {har_rain}")

#) punjab rain data
punjab_df = new_df[new_df['SUBDIVISION'] == 'PUNJAB']
punjab_rain = punjab_df['vol'].mean()
print(f"orissa rain: {orissa_rain}")

#) himachal rain data
himachal_df = new_df[new_df['SUBDIVISION'] == 'HIMACHAL PRADESH']
himachal_rain = himachal_df['vol'].mean()
print(f"himachal rain: {himachal_rain}")

#) JAMMU & KASHMIR rain data
jk_df = new_df[new_df['SUBDIVISION'] == 'JAMMU & KASHMIR']
jk_rain = jk_df['vol'].mean()
print(f"JAMMU & KASHMIR rain: {orissa_rain}")

#) west rajasthan rain data
w_rajasthan_df = new_df[new_df['SUBDIVISION'] == 'WEST RAJASTHAN']
w_rajasthan_rain = w_rajasthan_df['vol'].mean()
print(f"west rajasthan rain: {w_rajasthan_rain}")

#) east rajasthan rain data
e_rajasthan_df = new_df[new_df['SUBDIVISION'] == 'EAST RAJASTHAN']
e_rajasthan_rain = e_rajasthan_df['vol'].mean()
print(f"eest rajasthan rain: {e_rajasthan_rain}")

#) west mp rain data
wmp_df = new_df[new_df['SUBDIVISION'] == 'WEST MADHYA PRADESH']
wmp_rain = wmp_df['vol'].mean()
print(f"west mp rain: {wmp_rain}")

#) east mp rain data
emp_df = new_df[new_df['SUBDIVISION'] == 'EAST MADHYA PRADESH']
emp_rain = emp_df['vol'].mean()
print(f"west mp rain: {emp_rain}")

#) guj rain data
guj_df = new_df[new_df['SUBDIVISION'] == 'GUJARAT REGION']
guj_rain = guj_df['vol'].mean()
print(f"gujarat rain: {guj_rain}")

#) kutch rain data
kutch_df = new_df[new_df['SUBDIVISION'] == 'SAURASHTRA & KUTCH']
kutch_df
kutch_rain = kutch_df['vol'].mean()
print(f"kutch and saurashtra rain: {kutch_rain}")

#) konkan and goa rain data
goa_df = new_df[new_df['SUBDIVISION'] == 'KONKAN & GOA']
goa_rain = goa_df['vol'].mean()
print(f"konkan and goa rain: {goa_rain}")

#) madhya maharashtra rain data
mmah_df = new_df[new_df['SUBDIVISION'] == 'MADHYA MAHARASHTRA']
mmah_rain = mmah_df['vol'].mean()
print(f"MADHYA MAHARASHTRA rain: {mmah_rain}")

#) mathathwadha rain data
mathathwadha_df = new_df[new_df['SUBDIVISION'] == 'MATATHWADA']
mathathwadha_rain = mathathwadha_df['vol'].mean()
print(f"MATATHWADA rain: {mathathwadha_rain}")

#) vidharbha rain data
vidharbha_df = new_df[new_df['SUBDIVISION'] == 'VIDARBHA']
vidharbha_rain = vidharbha_df['vol'].mean()
print(f"vidharbha and goa rain: {vidharbha_rain}")

#) chatisgarh rain data
hatisgarh_df = new_df[new_df['SUBDIVISION'] == 'CHHATTISGARH']
hatisgarh_rain = hatisgarh_df['vol'].mean()
print(f"hatisgarh rain: {hatisgarh_rain}")

#) coastal ap rain data
coastalap_df = new_df[new_df['SUBDIVISION'] == 'COASTAL ANDHRA PRADESH']
coastalap_rain = coastalap_df['vol'].mean()
print(f"coastal ap rain: {coastalap_rain}")

#) telungana rain data
telungana_df = new_df[new_df['SUBDIVISION'] == 'TELANGANA']
telungana_rain = telungana_df['vol'].mean()
print(f"telungana rain: {telungana_rain}")

#) rayalseema rain data
rayalseema_df = new_df[new_df['SUBDIVISION'] == 'RAYALSEEMA']
rayalseema_rain = rayalseema_df['vol'].mean()
print(f"rayalseema rain: {rayalseema_rain}")

#) tamil rain data
tamil_df = new_df[new_df['SUBDIVISION'] == 'TAMIL NADU']
tamil_rain = goa_df['vol'].mean()
print(f"tamindau rain: {tamil_rain}")

#) coastal kannada rain data
ckannada_df = new_df[new_df['SUBDIVISION'] == 'COASTAL KARNATAKA']
ckannada_rain = ckannada_df['vol'].mean()
print(f"coastal kannada rain: {ckannada_rain}")
 
#) north interior knnada rain data
n_ikannada_df = new_df[new_df['SUBDIVISION'] == 'NORTH INTERIOR KARNATAKA']
n_ikannada_rain = n_ikannada_df['vol'].mean()
print(f"north interior knnada rain: {n_ikannada_rain}")

#) south interior knnada rain data
s_ikannada_df = new_df[new_df['SUBDIVISION'] == 'SOUTH INTERIOR KARNATAKA']
s_ikannada_rain = s_ikannada_df['vol'].mean()
print(f"north interior knnada rain: {s_ikannada_rain}")

#) kerala rain data
kerala_df = new_df[new_df['SUBDIVISION'] == 'KERALA']
kerala_rain = kerala_df['vol'].mean()
print(f"kerala rain: {kerala_rain}")


#) lakshadweep rain data
lakshadweep_df = new_df[new_df['SUBDIVISION'] == 'LAKSHADWEEP']
lakshadweep_rain = lakshadweep_df['vol'].mean()
print(f"lakshadweep rain: {lakshadweep_rain}")
# Out:
# andhaman rain: 243.99681818181818
# arunachal rain: 286.8682989690721
# assam rain: 215.0581884057971
# naga rain: 202.80318840579713
# himalaya rain: 229.35028985507248
# gangestic rain: 124.20782608695652
# jarkhand rain: 109.1086956521739
# bihar rain: 99.80311594202898
# east UP rain: 81.60079710144927
# orissa rain: 121.51427536231883
# west UP rain: 68.92586956521738
# uk rain: 122.14108695652175
# haryana delhi and chandigarh rain: 44.207536231884056
# orissa rain: 121.51427536231883
# himachal rain: 105.02833333333334
# JAMMU & KASHMIR rain: 121.51427536231883
# west rajasthan rain: 24.388623188405795
# eest rajasthan rain: 54.60079710144928
# west mp rain: 78.47804347826087
# west mp rain: 100.41695652173915
# gujarat rain: 76.51644927536232
# kutch and saurashtra rain: 41.26195652173913
# konkan and goa rain: 248.13978260869567
# MADHYA MAHARASHTRA rain: 73.35195652173914
# MATATHWADA rain: 65.88978260869565
# vidharbha and goa rain: 91.28855072463767
# hatisgarh rain: 114.31101449275363
# coastal ap rain: 87.74195652173913
# telungana rain: 79.4476811594203
# rayalseema rain: 63.85050724637682
# tamindau rain: 248.13978260869567
# coastal kannada rain: 283.82847826086953
# north interior knnada rain: 59.81615942028985
# north interior knnada rain: 86.69833333333334
# kerala rain: 243.79159420289852
# lakshadweep rain: 133.05709064327485

# %%
new_df['SUBDIVISION'].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
#) orissa plot
plt.figure(figsize=(15,10))
sns.scatterplot(data=orissa_df,x="YEAR",y="vol",hue='month' )
plt.show()

# %%
new_df['SUBDIVISION'].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
#) ml prediction
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

#new_df = pd.get_dummies(new_df,['SUBDIVISION','month'])
X = new_df.drop(['vol'],axis=1)
y = new_df['vol']

model = LinearRegression()
model.fit(X,y)
new_df['prediction'] = model.predict(X)
mse = mean_squared_error(new_df['vol'],new_df['prediction'])
print(mse)
# Out:
# 13435.815664274924

# %%
#)ridge
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

model = Ridge()
model.fit(x_train,y_train)
train_pred = model.predict(x_train)
test_pred = model.predict(x_test)

print("********Train data*********")
print(mean_squared_error(y_train,train_pred))

print("********Test data*********")
print(mean_squared_error(y_test,test_pred))
# Out:
# ********Train data*********
# 13532.863401028213
# ********Test data*********
# 13063.477775421841
